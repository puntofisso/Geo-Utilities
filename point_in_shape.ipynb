# %%
import pandas as pd
df = pd.read_csv('dft.csv')

# %%
df.head()
# Out:
#    count_point_id  year  region_id               region_name  \
# 0            6009  2018          8  Yorkshire and The Humber
# 1            6055  2018          8  Yorkshire and The Humber
# 2            6063  2018          8  Yorkshire and The Humber
# 3            6578  2018          8  Yorkshire and The Humber
# 4            6595  2018          8  Yorkshire and The Humber
#
#    local_authority_id local_authority_name road_name road_type  \
# 0                  63                Leeds      M621     major
# 1                  63                Leeds       M62     major
# 2                  63                Leeds      M621     major
# 3                  63                Leeds       A58     major
# 4                  63                Leeds       A61     major
#
#   start_junction_road_name end_junction_road_name  ...  buses_and_coaches  \
# 0                        7                     M1  ...                227
# ...

# %%
import json
from shapely.geometry import shape, Point
# depending on your version, use: from shapely.geometry import shape, Point

# load GeoJSON file containing sectors
with open('shape.json') as f:
    js = json.load(f)

# %%
# iterate on the dataframe - THIS IS INELEGANT, YOUY SHOULD USE df.apply()
for index, row in df.iterrows():
    lat = row['latitude']
    lon = row['longitude']
    count_point_id = row['count_point_id']

    point = Point(lon,lat)

    # check each polygon to see if it contains the point
    for feature in js['features']:
        polygon = shape(feature['geometry'])
        if polygon.contains(point):
            print(str(count_point_id) + ' YES')
        else:
            print(str(count_point_id) + ' NO')
# Out:
# 6009 NO
# 6055 NO
# 6063 NO
# 6578 NO
# 6595 NO
# 6607 NO
# 6613 NO
# 7398 NO
# 7402 NO
# 7403 NO
# 7410 YES
# 7415 NO
# 7418 NO
# 7422 NO
# 7755 YES
# 7850 YES
# 8263 NO
# 8348 NO
# 8538 NO
# 8540 YES
# 8548 NO
# 8554 YES
# 16054 NO
# 16562 NO
# 16576 YES
# 16590 YES
# 16593 YES
# 16598 YES
# 17366 NO
# 17369 NO
# 17370 NO
# 17372 NO
# 17373 NO
# 17374 YES
# 17719 YES
# 17721 YES
# 17950 YES
# 18247 NO
# 18451 YES
# 18655 NO
# 26007 NO
# 26074 YES
# 26091 NO
# 26603 YES
# 26613 NO
# 26618 YES
# 26625 NO
# 27414 NO
# 27428 YES
# 27432 NO
# 27436 NO
# 27439 YES
# 27442 NO
# 27443 NO
# 27802 NO
# 27827 NO
# 27833 YES
# 28003 YES
# 28005 YES
# 28237 NO
# 28289 YES
# 28291 YES
# 36055 NO
# 36089 NO
# 36603 YES
# 36604 NO
# 36619 NO
# 36620 YES
# 36634 NO
# 36642 NO
# 37463 NO
# 37477 YES
# 37488 NO
# 37489 NO
# 37861 YES
# 37867 NO
# 38343 NO
# 46069 YES
# 46600 NO
# 46614 YES
# 46625 YES
# 46630 NO
# 46633 YES
# 47438 NO
# 47443 NO
# 47446 NO
# 47449 NO
# 47451 NO
# 47808 NO
# 47827 NO
# ...
